# %%
#Importing the modules

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import mplsoccer.pitch as Pitch
import seaborn as sns

# %%
# Reading the dataset

df =pd.read_csv('Downloads\events (3).csv')

# %%
df
# Out:
#    Team Player Event  Mins  Secs   X   Y X2 Y2
# 0  Away     A1  Shot     0     0  13  63  -  -
# 1  Home     H1  Shot     0     0  19  77  -  -
# 2  Home     H3  Shot     0     1  26  21  -  -
# 3  Away     A2  Shot     0     1  73  50  -  -
# 4  Away     A2  Shot     0     1  26  48  -  -

# %%
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch

pitch = Pitch()
# specifying figure size (width, height)
fig, ax = pitch.draw(figsize=(8, 4))

df_p = df[df['Player'] == 'A2']

plt.scatter(df['X'], df['Y'], c='#ea6969', s=150, alpha=0.9)

# downloads_path = 'C:/Users/arpit/Downloads/plot.jpg'
# fig.savefig(downloads_path, format='jpg')
# fig.savefig('plot.jpg', format='jpg')

# %%
pitch = Pitch(pitch_color='grass', line_color='white',
              stripe=True)  # optional stripes
fig, ax = pitch.draw()

plt.scatter(df['X'], df['Y'], c='#ea6969', s=150, alpha=0.9)
